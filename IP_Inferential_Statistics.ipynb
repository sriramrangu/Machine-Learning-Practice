# %% [markdown]
# <a href="https://colab.research.google.com/github/sriramrangu/Machine-Learning-Practice/blob/main/IP_Inferential_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inferential Statistics

# %%
import numpy as np
# import pandas as pd
from scipy import stats

# %% [markdown]
# ## T Test
# - One Sample
# - Two Sample
# ### One Sample T Test :
#       1. Two Tailed
#       2. One Tailed
#           i. Higher Tail
#           ii. Lower Tail

# %%
caffine_content = [78, 82, 85, 79, 81, 83, 80, 77, 84, 81]
avg_caffine_content = np.mean(caffine_content)
avg_caffine_content
# Out:
# np.float64(81.0)

# %%
caffine_content_2 = [72, 88, 95, 63, 81, 83, 80, 77, 84, 81]
avg_caffine_content_2 = np.mean(caffine_content_2)
avg_caffine_content_2
# Out:
# np.float64(80.4)
