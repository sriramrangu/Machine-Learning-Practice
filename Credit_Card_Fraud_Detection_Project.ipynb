# %% [markdown]
# <a href="https://colab.research.google.com/github/sriramrangu/Machine-Learning-Practice/blob/main/Credit_Card_Fraud_Detection_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import *

# %% [markdown]
# Dataset Link:https://drive.google.com/file/d/16cg5Ksa8pG6EhYfOrbKz9j_01SEjzpYT/view?usp=sharing

# %%
df = pd.read_csv("/content/creditcard (1).csv")
df
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %%
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  1.168375e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# for col in df.columns:
#   plt.plot(col)

# %%
scalar = StandardScaler()

# %%
df['Normalized_Amount'] = scalar.fit_transform(df[['Amount']])

# %%
df.head()
# Out:
#    Time        V1        V2  ...  Amount  Class  Normalized_Amount
# 0   0.0 -1.359807 -0.072781  ...  149.62      0           0.244200
# 1   0.0  1.191857  0.266151  ...    2.69      0          -0.342584
# 2   1.0 -1.358354 -1.340163  ...  378.66      0           1.158900
# 3   1.0 -0.966272 -0.185226  ...  123.50      0           0.139886
# 4   2.0 -1.158233  0.877737  ...   69.99      0          -0.073813
#
# [5 rows x 32 columns]

# %%
df.drop(columns=['Amount'],inplace = True)

# %%
df
# Out:
#             Time         V1         V2  ...       V28  Class  Normalized_Amount
# 0            0.0  -1.359807  -0.072781  ... -0.021053      0           0.244200
# 1            0.0   1.191857   0.266151  ...  0.014724      0          -0.342584
# 2            1.0  -1.358354  -1.340163  ... -0.059752      0           1.158900
# 3            1.0  -0.966272  -0.185226  ...  0.061458      0           0.139886
# 4            2.0  -1.158233   0.877737  ...  0.215153      0          -0.073813
# ...          ...        ...        ...  ...       ...    ...                ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731      0          -0.350252
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527      0          -0.254325
# 284804  172788.0   1.919565  -0.301254  ... -0.026561      0          -0.082239
# 284805  172788.0  -0.240440   0.530483  ...  0.104533      0          -0.313391
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649      0           0.513290
#
# ...

# %%
X = df.drop(columns=['Class'])
y = df['Class']

# %%
X
# Out:
#             Time         V1         V2  ...       V27       V28  Amount
# 0            0.0  -1.359807  -0.072781  ...  0.133558 -0.021053  149.62
# 1            0.0   1.191857   0.266151  ... -0.008983  0.014724    2.69
# 2            1.0  -1.358354  -1.340163  ... -0.055353 -0.059752  378.66
# 3            1.0  -0.966272  -0.185226  ...  0.062723  0.061458  123.50
# 4            2.0  -1.158233   0.877737  ...  0.219422  0.215153   69.99
# ...          ...        ...        ...  ...       ...       ...     ...
# 284802  172786.0 -11.881118  10.071785  ...  0.943651  0.823731    0.77
# 284803  172787.0  -0.732789  -0.055080  ...  0.068472 -0.053527   24.79
# 284804  172788.0   1.919565  -0.301254  ...  0.004455 -0.026561   67.88
# 284805  172788.0  -0.240440   0.530483  ...  0.108821  0.104533   10.00
# 284806  172792.0  -0.533413  -0.189733  ... -0.002415  0.013649  217.00
#
# [283726 rows x 30 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 283726, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
X_train.shape
# Out:
# (226980, 30)

# %%
X_test.shape
# Out:
# (56746, 30)

# %%
print(y_train.value_counts())
# Out:
# Class
# 0    226597
# 1       383
# Name: count, dtype: int64

# %%
# !pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)

# %%
X_train_smote , y_train_smote = smote.fit_resample(X_train, y_train)

# %%
print("Before SMOTE : ", y_train.value_counts())
print("After SMOTE : ", y_train_smote.value_counts())
# Out:
# Before SMOTE :  Class
# 0    226597
# 1       383
# Name: count, dtype: int64
# After SMOTE :  Class
# 0    226597
# 1    226597
# Name: count, dtype: int64

# %% [markdown]
# 1. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(X_train_smote, y_train_smote)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dt.predict(X_test)

# %%
dt_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test, dt_pred)
# Out:
# 0.9978324463398301

# %%
precision_score(y_test, dt_pred)
# Out:
# 0.40350877192982454

# %%
recall_score(y_test, dt_pred)
# Out:
# 0.7666666666666667

# %%
print(classification_report(y_test, dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56656
#            1       0.40      0.77      0.53        90
#
#     accuracy                           1.00     56746
#    macro avg       0.70      0.88      0.76     56746
# weighted avg       1.00      1.00      1.00     56746
